# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' : {'$gte' : 20, '$lte': 20}}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Out:
# 41

# %%
# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64a0b203c0b07c9f12724eda'),
#  'geocode': {'latitude': 50.769705, 'longitude': None},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
#import pandas
import pandas as pd
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("rows in dataframe: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# rows in dataframe:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64a0b203c0b07c9f12724eda   110681                  0
# 1  64a0b203c0b07c9f12725245   612039                  0
# 2  64a0b203c0b07c9f1272554f   730933                  0
# 3  64a0b203c0b07c9f1272573e   172735                  0
# 4  64a0b203c0b07c9f12725763   172953                  0
# 5  64a0b203c0b07c9f127260eb   512854                  0
# 6  64a0b203c0b07c9f1272631d  1537089                  0
# 7  64a0b203c0b07c9f1272783a   155648                  0
# 8  64a0b203c0b07c9f12727c7b  1012883                  0
# 9  64a0b203c0b07c9f1272848f   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0         {'longitude': None, 'latitude': 50.769705}
# 1         {'longitude': None, 'latitude': 51.857536}
# 2         {'longitude': None, 'latitude': 51.789429}
# 3         {'longitude': None, 'latitude': 50.770885}
# 4         {'longitude': None, 'latitude': 50.770724}
# 5         {'longitude': None, 'latitude': 51.541448}
# 6        {'longitude': None, 'latitude': 51.5350065}
# 7         {'longitude': None, 'latitude': 51.591515}
# 8  {'longitude': None, 'latitude': 51.1859474182129}
# 9          {'longitude': None, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments in London with a RatingValue greater than or equal to 4.
london_query = {
    'AddressLine4' : 'London',
    'RatingValue'  : {'$gte': 4}
}
pprint(list(establishments.find(london_query)))
# Out:
# [{'AddressLine1': 'Arch D',
#   'AddressLine2': 'The Link Thamesmead',
#   'AddressLine3': 'Bazalgette Way',
#   'AddressLine4': 'London',
#   'BusinessName': 'The Mezzanine Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.357884390823,
#   'FHRSID': 1049722,
#   'LocalAuthorityBusinessID': '18/00096/CP',
#   'LocalAuthorityCode': '503',
#   'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#   'LocalAuthorityName': 'Bexley',
#   'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE2 9BS',
#   'RatingDate': '2022-05-24T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a378'),
#   'geocode': {'latitude': 51.5002632141113, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1049722',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 0}},
#  {'AddressLine1': 'St Edwards Church Hall',
#   'AddressLine2': 'St Keverne Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': "St Edward's Church, Mottingham - StEP Lunch Club / Food "
#                   'Bank',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4646.410907714035,
#   'FHRSID': 1261451,
#   'LocalAuthorityBusinessID': '20/00255/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4AA',
#   'RatingDate': '2022-04-22T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a398'),
#   'geocode': {'latitude': 51.428019, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1261451',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Mottingham Community Centre',
#   'AddressLine2': 'Kimmeridge Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Maryfield Pre-School 2',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.414830504498,
#   'FHRSID': 987733,
#   'LocalAuthorityBusinessID': '16/00340/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4EB',
#   'RatingDate': '2021-10-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a39e'),
#   'geocode': {'latitude': 51.4269142150879, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/987733',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'The Co-operative Food',
#   'AddressLine2': 'Kimmeridge Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Co-op',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.414830504498,
#   'FHRSID': 357627,
#   'LocalAuthorityBusinessID': '00000/0000/8/951',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4EB',
#   'RatingDate': '2022-09-01T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3a0'),
#   'geocode': {'latitude': 51.4269142150879, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357627',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Castlecombe Youth Centre',
#   'AddressLine2': 'Castlecombe Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'North Hub @ Castlecombe Youth Centre',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.439634658363,
#   'FHRSID': 1151706,
#   'LocalAuthorityBusinessID': '00000/0000/8/204',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4AT',
#   'RatingDate': '2022-05-18T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3bc'),
#   'geocode': {'latitude': 51.424388885498, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1151706',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': '11 Cranley Parade',
#   'AddressLine2': 'Kimmeridge Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Spencers',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.443676735867,
#   'FHRSID': 1468037,
#   'LocalAuthorityBusinessID': '22/00180/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4DZ',
#   'RatingDate': '2022-02-09T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3c0'),
#   'geocode': {'latitude': 51.427318, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1468037',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': '3 Cranley Parade',
#   'AddressLine2': 'Beaconsfield Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': "Domino's Pizza",
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.443676735867,
#   'FHRSID': 358232,
#   'LocalAuthorityBusinessID': '02/00010/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4DZ',
#   'RatingDate': '2019-11-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3c1'),
#   'geocode': {'latitude': 51.427318, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/358232',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '4 Cranley Parade',
#   'AddressLine2': 'Beaconsfield Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': "Papa John's Pizza",
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.4482563738065,
#   'FHRSID': 1415217,
#   'LocalAuthorityBusinessID': '21/00630/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4DZ',
#   'RatingDate': '2022-01-27T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3c9'),
#   'geocode': {'latitude': 51.4273993, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1415217',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '11 Beaconsfield Parade',
#   'AddressLine2': 'Beaconsfield Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Perfect Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.46427738734,
#   'FHRSID': 635108,
#   'LocalAuthorityBusinessID': '14/00056/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4EA',
#   'RatingDate': '2018-07-31T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3dd'),
#   'geocode': {'latitude': 51.427186, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/635108',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '12 Beaconsfield Parade',
#   'AddressLine2': 'Beaconsfield Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Superfry Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.46427738734,
#   'FHRSID': 357579,
#   'LocalAuthorityBusinessID': '00000/0000/8/062',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4EA',
#   'RatingDate': '2021-06-30T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3de'),
#   'geocode': {'latitude': 51.427186, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357579',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}},
#  {'AddressLine1': '3 Beaconsfield Parade',
#   'AddressLine2': 'Kimmeridge Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'China Jade',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.46427738734,
#   'FHRSID': 357632,
#   'LocalAuthorityBusinessID': '00000/0000/8/975',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4EA',
#   'RatingDate': '2021-09-22T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a3e0'),
#   'geocode': {'latitude': 51.427186, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357632',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'The Gefferys Estate Community Hall',
#   'AddressLine2': '27 Nunnington Close',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': "Geffery's Hall Community Centre & Foodbank",
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4646.545195742962,
#   'FHRSID': 1303314,
#   'LocalAuthorityBusinessID': '20/00712/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4TA',
#   'RatingDate': '2021-08-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a43b'),
#   'geocode': {'latitude': 51.4320831298828, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1303314',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'St Vincents Primary School',
#   'AddressLine2': 'Harting Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': "St Vincent's Breakfast Club",
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4646.582717070066,
#   'FHRSID': 987478,
#   'LocalAuthorityBusinessID': '12/00332/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4JR',
#   'RatingDate': '2020-02-25T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a46c'),
#   'geocode': {'latitude': 51.4291152954102, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/987478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'St Vincents Primary School',
#   'AddressLine2': 'Harting Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Fit 4 Future Group',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.582717070066,
#   'FHRSID': 1469968,
#   'LocalAuthorityBusinessID': '22/00222/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4JR',
#   'RatingDate': '2022-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b203c0b07c9f1272a46d'),
#   'geocode': {'latitude': 51.4291152954102, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1469968',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Methodist Church',
#   'AddressLine2': 'Mottingham Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Mottingham Methodist Church',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4646.861960893071,
#   'FHRSID': 708403,
#   'LocalAuthorityBusinessID': '00000/0002/3/400',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4QR',
#   'RatingDate': '2022-05-18T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272a668'),
#   'geocode': {'latitude': 51.436724, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/708403',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 10}},
#  {'AddressLine1': 'W G Grace Community Centre',
#   'AddressLine2': '1 Lions Close',
#   'AddressLine3': 'Grove Park',
#   'AddressLine4': 'London',
#   'BusinessName': 'Marvels Lane Pre-school',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.919488803341,
#   'FHRSID': 255044,
#   'LocalAuthorityBusinessID': 'PI/000096222',
#   'LocalAuthorityCode': '523',
#   'LocalAuthorityEmailAddress': 'david.edwards@lewisham.gov.uk',
#   'LocalAuthorityName': 'Lewisham',
#   'LocalAuthorityWebSite': 'http://www.lewisham.gov.uk/myservices/business/food-safety/Pages/default.aspx',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4HG',
#   'RatingDate': '2021-07-19T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272a6c1'),
#   'geocode': {'latitude': 51.430387, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/255044',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Mottingham Service Station',
#   'AddressLine2': '21 Mottingham Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'BP Connect And M&S Simply Food \\& Wild Bean Cafe',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.941750336222,
#   'FHRSID': 357648,
#   'LocalAuthorityBusinessID': '00000/0000/9/206',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4QN',
#   'RatingDate': '2021-04-27T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272a6f1'),
#   'geocode': {'latitude': 51.437849, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357648',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'London Marathon Sports Ground',
#   'AddressLine2': 'Grove Park Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Mottingham Sports Ground',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.959234089705,
#   'FHRSID': 357605,
#   'LocalAuthorityBusinessID': '00000/0000/8/634',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4QE',
#   'RatingDate': '2004-03-30T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272a71a'),
#   'geocode': {'latitude': 51.434816, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357605',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': 'London Marathon Sports Ground',
#   'AddressLine2': 'Grove Park Road',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Centymca Sports Ground',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.959234089705,
#   'FHRSID': 357606,
#   'LocalAuthorityBusinessID': '00000/0000/8/635',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4QE',
#   'RatingDate': '2004-03-09T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272a71d'),
#   'geocode': {'latitude': 51.434816, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/357606',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': 'Mottingham Hall Nursery',
#   'AddressLine2': 'Mottingham Lane',
#   'AddressLine3': 'Mottingham',
#   'AddressLine4': 'London',
#   'BusinessName': 'Mottingham Hall For Children',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4647.226201869891,
#   'FHRSID': 719603,
#   'LocalAuthorityBusinessID': '14/00343/FOOD',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE9 4RW',
#   'RatingDate': '2022-06-29T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272a913'),
#   'geocode': {'latitude': 51.439219, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/719603',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Bannatynes Health Club',
#   'AddressLine2': '35 Marvels Lane',
#   'AddressLine3': 'Grove Park',
#   'AddressLine4': 'London',
#   'BusinessName': "Bannatyne's Health Club",
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4647.502841857197,
#   'FHRSID': 358238,
#   'LocalAuthorityBusinessID': '02/00031/MIXED',
#   'LocalAuthorityCode': '505',
#   'LocalAuthorityEmailAddress': 'food@bromley.gov.uk',
#   'LocalAuthorityName': 'Bromley',
#   'LocalAuthorityWebSite': 'http://www.bromley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE12 9PN',
#   'RatingDate': '2022-02-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272aa0c'),
#   'geocode': {'latitude': 51.435644, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/358238',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Cedar Court',
#   'AddressLine2': '9-13 Somertrees Avenue',
#   'AddressLine3': 'Grove Park',
#   'AddressLine4': 'London',
#   'BusinessName': 'Cedar Court Care Home',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4647.528348766282,
#   'FHRSID': 1475272,
#   'LocalAuthorityBusinessID': 'PI/000304665',
#   'LocalAuthorityCode': '523',
#   'LocalAuthorityEmailAddress': 'david.edwards@lewisham.gov.uk',
#   'LocalAuthorityName': 'Lewisham',
#   'LocalAuthorityWebSite': 'http://www.lewisham.gov.uk/myservices/business/food-safety/Pages/default.aspx',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE12 0LR',
#   'RatingDate': '2022-04-19T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272aa31'),
#   'geocode': {'latitude': 51.434825, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1475272',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Woodman Community Centre',
#   'AddressLine2': 'Woodman Street',
#   'AddressLine3': 'North Woolwich',
#   'AddressLine4': 'London',
#   'BusinessName': 'RCCG Christ Chapel For All Nations',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.3917646886275,
#   'FHRSID': 1286601,
#   'LocalAuthorityBusinessID': '20/00551/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2NF',
#   'RatingDate': '2021-02-24T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272ad9c'),
#   'geocode': {'latitude': 51.501392364502, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1286601',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}},
#  {'AddressLine1': 'Depot DLR',
#   'AddressLine2': 'Armada Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Aramark',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.417358012797,
#   'FHRSID': 849319,
#   'LocalAuthorityBusinessID': '60725/2000/2/000',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E6 7FB',
#   'RatingDate': '2018-09-27T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272adb8'),
#   'geocode': {'latitude': 51.512167, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/849319',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '1 Woodman Parade',
#   'AddressLine2': 'Woodman Street',
#   'AddressLine3': 'North Woolwich',
#   'AddressLine4': 'London',
#   'BusinessName': 'Cromwell Stores Off Licence',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.512067108131,
#   'FHRSID': 864062,
#   'LocalAuthorityBusinessID': '11/00302/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2LL',
#   'RatingDate': '2017-08-16T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272ae36'),
#   'geocode': {'latitude': 51.501123, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/864062',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '5 Woodman Parade',
#   'AddressLine2': 'Woodman Street',
#   'AddressLine3': 'North Woolwich',
#   'AddressLine4': 'London',
#   'BusinessName': 'Day Lewis Pharmacy',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.512067108131,
#   'FHRSID': 846605,
#   'LocalAuthorityBusinessID': '79490/1005/0/000',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2LL',
#   'RatingDate': '2018-11-19T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272ae37'),
#   'geocode': {'latitude': 51.501123, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/846605',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '4 Woodman Parade',
#   'AddressLine2': 'Woodman Street',
#   'AddressLine3': 'North Woolwich',
#   'AddressLine4': 'London',
#   'BusinessName': 'FM & Co General Store',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.512067108131,
#   'FHRSID': 864082,
#   'LocalAuthorityBusinessID': '13/01196/COMM',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2LL',
#   'RatingDate': '2020-03-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272ae38'),
#   'geocode': {'latitude': 51.501123, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/864082',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Unit 56',
#   'AddressLine2': 'Riverdale Centre',
#   'AddressLine3': 'Hither Green',
#   'AddressLine4': 'London',
#   'BusinessName': 'Poundland',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.52617257704,
#   'FHRSID': 256860,
#   'LocalAuthorityBusinessID': 'PI/000176968',
#   'LocalAuthorityCode': '523',
#   'LocalAuthorityEmailAddress': 'david.edwards@lewisham.gov.uk',
#   'LocalAuthorityName': 'Lewisham',
#   'LocalAuthorityWebSite': 'http://www.lewisham.gov.uk/myservices/business/food-safety/Pages/default.aspx',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2017-02-25T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272ae46'),
#   'geocode': {'latitude': 51.4492500001303, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/256860',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'St Johns Green Community Kiosk',
#   'AddressLine2': 'Albert Road',
#   'AddressLine3': 'North Woolwich',
#   'AddressLine4': 'London',
#   'BusinessName': 'Fusion Foods Pop Up Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.690509744222,
#   'FHRSID': 1333657,
#   'LocalAuthorityBusinessID': '21/00028/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2JB',
#   'RatingDate': '2021-08-26T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af4e'),
#   'geocode': {'latitude': 51.5008010864258, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1333657',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'University Of East London Dockland',
#   'AddressLine2': 'University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Starbucks Outlet',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132138,
#   'LocalAuthorityBusinessID': '19/00456/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af4f'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132138',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'University Of East London Dockland',
#   'AddressLine2': 'University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': '53.5 Degrees',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132140,
#   'LocalAuthorityBusinessID': '19/00459/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-10T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af50'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132140',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Eastern Academic Building',
#   'AddressLine2': '4 - 6 University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Papa Johns Outlet',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132118,
#   'LocalAuthorityBusinessID': '19/00427/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af51'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132118',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Eastern Academic Building',
#   'AddressLine2': '4 - 6 University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Sports Dock',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132120,
#   'LocalAuthorityBusinessID': '19/00430/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af52'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132120',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Eastern Academic Building',
#   'AddressLine2': '4 - 6 University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Costa Outlet',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132125,
#   'LocalAuthorityBusinessID': '19/00435/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-10T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af53'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132125',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'University Of East London Dockland',
#   'AddressLine2': 'University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Edge Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132136,
#   'LocalAuthorityBusinessID': '19/00452/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-10T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af54'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132136',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}},
#  {'AddressLine1': 'University Of East London Dockland',
#   'AddressLine2': 'University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Underground Bar',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132137,
#   'LocalAuthorityBusinessID': '19/00454/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af55'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132137',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'University Of East London Dockland',
#   'AddressLine2': 'University Way',
#   'AddressLine3': 'Beckton',
#   'AddressLine4': 'London',
#   'BusinessName': 'Aramark Shop',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4648.697238979209,
#   'FHRSID': 1132139,
#   'LocalAuthorityBusinessID': '19/00457/FOOD',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2RD',
#   'RatingDate': '2019-05-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272af56'),
#   'geocode': {'latitude': 51.507405, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1132139',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
# ...
#   'RatingDate': '2020-12-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c05c'),
#   'geocode': {'latitude': 51.54305, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1276517',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'The Alphabet House',
#   'AddressLine2': '37 Windmill Lane',
#   'AddressLine3': 'Stratford',
#   'AddressLine4': 'London',
#   'BusinessName': 'The Alphabet House Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4652.418347800144,
#   'FHRSID': 641180,
#   'LocalAuthorityBusinessID': '79270/2004/3/000',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E15 1PG',
#   'RatingDate': '2020-01-29T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c097'),
#   'geocode': {'latitude': 51.545498, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/641180',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Ronald Openshaw Nursery Education C',
#   'AddressLine2': 'Henniker Road',
#   'AddressLine3': 'Stratford',
#   'AddressLine4': 'London',
#   'BusinessName': 'Ronald Openshaw Nursery',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4652.5577598666805,
#   'FHRSID': 640942,
#   'LocalAuthorityBusinessID': '68870/2002/2/000',
#   'LocalAuthorityCode': '525',
#   'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#   'LocalAuthorityName': 'Newham',
#   'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E15 1JP',
#   'RatingDate': '2018-09-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c0ba'),
#   'geocode': {'latitude': 51.548851, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640942',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Hermon Hill Methodist Church',
#   'AddressLine2': 'Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Daisy Chain Preschool',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4652.88521570684,
#   'FHRSID': 732377,
#   'LocalAuthorityBusinessID': '180778',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E11 2AR',
#   'RatingDate': '2019-09-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c1cf'),
#   'geocode': {'latitude': 51.582160949707, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/732377',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': '48 Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Forest Dene RCH',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4652.900757067453,
#   'FHRSID': 444154,
#   'LocalAuthorityBusinessID': '58886',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E11 2AP',
#   'RatingDate': '2022-03-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c1d5'),
#   'geocode': {'latitude': 51.581675, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/444154',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': '56 Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Little Diamonds Ltd',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4652.948992683083,
#   'FHRSID': 809984,
#   'LocalAuthorityBusinessID': '181333',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E11 1PB',
#   'RatingDate': '2022-03-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c1ef'),
#   'geocode': {'latitude': 51.583712, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/809984',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Holy Trinity Church Hall',
#   'AddressLine2': 'Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Trinity Hall Kindergarden',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4652.969989557179,
#   'FHRSID': 765705,
#   'LocalAuthorityBusinessID': '181013',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E18 1QQ',
#   'RatingDate': '2020-01-14T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c20a'),
#   'geocode': {'latitude': 51.588362, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/765705',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': '126 Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Gaks Wines',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4652.977857848684,
#   'FHRSID': 443411,
#   'LocalAuthorityBusinessID': '157957',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E18 1QB',
#   'RatingDate': '2021-07-17T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c20d'),
#   'geocode': {'latitude': 51.586457, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/443411',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': '132 Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Ookii Sushi',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4652.983846403214,
#   'FHRSID': 1415946,
#   'LocalAuthorityBusinessID': '201364',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E18 1QH',
#   'RatingDate': '2022-03-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c210'),
#   'geocode': {'latitude': 51.587539, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1415946',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': '142 Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Ark Fish Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4652.993771193876,
#   'FHRSID': 443503,
#   'LocalAuthorityBusinessID': '164134',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E18 1QH',
#   'RatingDate': '2019-11-28T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c22b'),
#   'geocode': {'latitude': 51.588427, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/443503',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': '136 Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Yummy Thai',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4652.993771193876,
#   'FHRSID': 622783,
#   'LocalAuthorityBusinessID': '180256',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E18 1QH',
#   'RatingDate': '2021-11-28T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c22c'),
#   'geocode': {'latitude': 51.588427, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/622783',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': '160 Hermon Hill',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Sakura-Sushi Buns',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4652.993771193876,
#   'FHRSID': 1015143,
#   'LocalAuthorityBusinessID': '198461',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E18 1QH',
#   'RatingDate': '2022-03-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c22e'),
#   'geocode': {'latitude': 51.588427, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1015143',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '',
#   'AddressLine2': 'Woodford New Road',
#   'AddressLine3': '',
#   'AddressLine4': 'London',
#   'BusinessName': 'Woodford Service Station',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4653.947633148593,
#   'FHRSID': 443402,
#   'LocalAuthorityBusinessID': '157193',
#   'LocalAuthorityCode': '526',
#   'LocalAuthorityEmailAddress': 'themis.skouros@redbridge.gov.uk',
#   'LocalAuthorityName': 'Redbridge',
#   'LocalAuthorityWebSite': 'http://www.redbridge.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E18 2QD',
#   'RatingDate': '2021-08-31T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64a0b204c0b07c9f1272c3f7'),
#   'geocode': {'latitude': 51.599716, 'longitude': None},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/443402',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}]

# %%
# Use count_documents to display the number of documents in the result
establishments.count_documents(london_query)

# Display the first document in the results using pprint
london_results = establishments.find(london_query)
pprint(london_results[0])
# Out:
# {'AddressLine1': 'Arch D',
#  'AddressLine2': 'The Link Thamesmead',
#  'AddressLine3': 'Bazalgette Way',
#  'AddressLine4': 'London',
#  'BusinessName': 'The Mezzanine Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.357884390823,
#  'FHRSID': 1049722,
#  'LocalAuthorityBusinessID': '18/00096/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE2 9BS',
#  'RatingDate': '2022-05-24T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64a0b203c0b07c9f1272a378'),
#  'geocode': {'latitude': 51.5002632141113, 'longitude': None},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1049722',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(london_results)

# Display the number of rows in the DataFrame
print("rows in dataframe: ", len(london_df))

# Display the first 10 rows of the DataFrame
london_df.head(10)
# Out:
# rows in dataframe:  390
#                         _id   FHRSID  ChangesByServerID  \
# 0  64a0b203c0b07c9f1272a378  1049722                  0
# 1  64a0b203c0b07c9f1272a398  1261451                  0
# 2  64a0b203c0b07c9f1272a39e   987733                  0
# 3  64a0b203c0b07c9f1272a3a0   357627                  0
# 4  64a0b203c0b07c9f1272a3bc  1151706                  0
# 5  64a0b203c0b07c9f1272a3c0  1468037                  0
# 6  64a0b203c0b07c9f1272a3c1   358232                  0
# 7  64a0b203c0b07c9f1272a3c9  1415217                  0
# 8  64a0b203c0b07c9f1272a3dd   635108                  0
# 9  64a0b203c0b07c9f1272a3de   357579                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0              18/00096/CP                                 The Mezzanine Cafe
# 1           20/00255/MIXED  St Edward's Church, Mottingham - StEP Lunch Cl...
# 2           16/00340/MIXED                             Maryfield Pre-School 2
# 3         00000/0000/8/951                                              Co-op
# 4         00000/0000/8/204               North Hub @ Castlecombe Youth Centre
# 5           22/00180/MIXED                                           Spencers
# 6           02/00010/MIXED                                     Domino's Pizza
# 7           21/00630/MIXED                                  Papa John's Pizza
# 8           14/00056/MIXED                                       Perfect Cafe
# 9         00000/0000/8/062                                  Superfry Fish Bar
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1                Other catering premises            7841
# 2                        Caring Premises               5
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                        Caring Premises               5
# 5                      Retailers - other            4613
# 6                 Takeaway/sandwich shop            7844
# 7                 Takeaway/sandwich shop            7844
# 8                Restaurant/Cafe/Canteen               1
# 9                 Takeaway/sandwich shop            7844
#
#                   AddressLine1         AddressLine2    AddressLine3  ...  \
# 0                       Arch D  The Link Thamesmead  Bazalgette Way  ...
# 1       St Edwards Church Hall      St Keverne Road      Mottingham  ...
# 2  Mottingham Community Centre      Kimmeridge Road      Mottingham  ...
# 3        The Co-operative Food      Kimmeridge Road      Mottingham  ...
# 4     Castlecombe Youth Centre     Castlecombe Road      Mottingham  ...
# 5            11 Cranley Parade      Kimmeridge Road      Mottingham  ...
# 6             3 Cranley Parade    Beaconsfield Road      Mottingham  ...
# 7             4 Cranley Parade    Beaconsfield Road      Mottingham  ...
# 8       11 Beaconsfield Parade    Beaconsfield Road      Mottingham  ...
# 9       12 Beaconsfield Parade    Beaconsfield Road      Mottingham  ...
#
#        LocalAuthorityWebSite LocalAuthorityEmailAddress  \
# 0   http://www.bexley.gov.uk  food.safety@bexley.gov.uk
# 1  http://www.bromley.gov.uk        food@bromley.gov.uk
# 2  http://www.bromley.gov.uk        food@bromley.gov.uk
# 3  http://www.bromley.gov.uk        food@bromley.gov.uk
# 4  http://www.bromley.gov.uk        food@bromley.gov.uk
# 5  http://www.bromley.gov.uk        food@bromley.gov.uk
# 6  http://www.bromley.gov.uk        food@bromley.gov.uk
# 7  http://www.bromley.gov.uk        food@bromley.gov.uk
# 8  http://www.bromley.gov.uk        food@bromley.gov.uk
# 9  http://www.bromley.gov.uk        food@bromley.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 10, 'Structural': 0, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 5  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...        FHRS
# 6  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': None, 'latitude': 51.5002632141113}
# 1         {'longitude': None, 'latitude': 51.428019}
# 2  {'longitude': None, 'latitude': 51.4269142150879}
# 3  {'longitude': None, 'latitude': 51.4269142150879}
# 4   {'longitude': None, 'latitude': 51.424388885498}
# 5         {'longitude': None, 'latitude': 51.427318}
# 6         {'longitude': None, 'latitude': 51.427318}
# 7        {'longitude': None, 'latitude': 51.4273993}
# 8         {'longitude': None, 'latitude': 51.427186}
# 9         {'longitude': None, 'latitude': 51.427186}
#
#       Distance NewRatingPending  \
# 0  4646.357884            False
# 1  4646.410908            False
# 2  4646.414831            False
# 3  4646.414831            False
# 4  4646.439635            False
# 5  4646.443677            False
# 6  4646.443677            False
# 7  4646.448256            False
# 8  4646.464277            False
# 9  4646.464277            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}

# 2. Group the matches by Local Authority
group_query = {'$group': {'_id' : '$LocalAuthorityName', 'count': {'$sum': 1}}}

# 3. Sorts the matches from highest to lowest
sort = {'$sort': {'count': -1}}
pipeline = [match_query, group_query, sort]
hygiene_results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
print("Number of establishments with a hygiene score of 0: ", len(hygiene_results))
# Print the first 10 results
pprint(hygiene_results[0:10])
# Out:
# Number of establishments with a hygiene score of 0:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_df = pd.DataFrame(hygiene_results)
# Display the number of rows in the DataFrame
print("rows in dataframe: ", len(hygiene_df))
# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# rows in dataframe:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
